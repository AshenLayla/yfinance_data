# %%
import pandas as pd
import yfinance as yf
from requests_cache import CachedSession

# Create a cached session
session = CachedSession('yfinance.cache')
session.headers['User-agent'] = 'my-program/1.0'

# Get the S&P 500 tickers
sp500_tickers = pd.read_html('https://en.wikipedia.org/wiki/List_of_S%26P_500_companies')[0]['Symbol'].values.tolist()

# Loop through each ticker and download the data
for ticker in sp500_tickers:
    try:
        ticker_obj = yf.Ticker(ticker, session=session)
        data = {
            'info': ticker_obj.info,
            'financials': ticker_obj.financials,
            'quarterly_financials': ticker_obj.quarterly_financials,
            'balance_sheet': ticker_obj.balance_sheet,
            'quarterly_balance_sheet': ticker_obj.quarterly_balance_sheet,
            'cashflow': ticker_obj.cashflow,
            'quarterly_cashflow': ticker_obj.quarterly_cashflow,
        }
        
        # Create a separate Excel file for each stock
        with pd.ExcelWriter(f'{ticker}.xlsx') as writer:
            for key, value in data.items():
                if isinstance(value, pd.DataFrame):
                    value.to_excel(writer, sheet_name=key, index=False)
                else:
                    pd.DataFrame([value]).to_excel(writer, sheet_name=key, index=False)
        
        print(f"Data saved for {ticker}")
    except Exception as e:
        print(f"Error downloading data for {ticker}: {e}")
# Out:
# Data saved for MMM
# Data saved for AOS
# Data saved for ABT
# Data saved for ABBV
# Data saved for ACN
# Data saved for ADBE
# Data saved for AMD
# Data saved for AES
# Data saved for AFL
# Data saved for A
# Data saved for APD
# Data saved for ABNB
# Data saved for AKAM
# Data saved for ALB
# Data saved for ARE
# Data saved for ALGN
# Data saved for ALLE
# Data saved for LNT
# Data saved for ALL
# Data saved for GOOGL
# Data saved for GOOG
# Data saved for MO
# Data saved for AMZN
# Data saved for AMCR
# Data saved for AEE
# Data saved for AAL
# Data saved for AEP
# Data saved for AXP
# Data saved for AIG
# Data saved for AMT
# Data saved for AWK
# Data saved for AMP
# Data saved for AME
# Data saved for AMGN
# Data saved for APH
# Data saved for ADI
# Data saved for ANSS
# Data saved for AON
# Data saved for APA
# Data saved for AAPL
# Data saved for AMAT
# Data saved for APTV
# Data saved for ACGL
# Data saved for ADM
# Data saved for ANET
# Data saved for AJG
# Data saved for AIZ
# Data saved for T
# Data saved for ATO
# Data saved for ADSK
# Data saved for ADP
# Data saved for AZO
# Data saved for AVB
# Data saved for AVY
# Data saved for AXON
# Data saved for BKR
# Data saved for BALL
# Data saved for BAC
# Data saved for BK
# Data saved for BBWI
# Data saved for BAX
# Data saved for BDX
# Data saved for BRK.B
# Data saved for BBY
# Data saved for BIO
# Data saved for TECH
# Data saved for BIIB
# Data saved for BLK
# Data saved for BX
# Data saved for BA
# Data saved for BKNG
# Data saved for BWA
# Data saved for BSX
# Data saved for BMY
# Data saved for AVGO
# Data saved for BR
# Data saved for BRO
# Data saved for BF.B
# Data saved for BLDR
# Data saved for BG
# Data saved for BXP
# Data saved for CDNS
# Data saved for CZR
# Data saved for CPT
# Data saved for CPB
# Data saved for COF
# Data saved for CAH
# Data saved for KMX
# Data saved for CCL
# Data saved for CARR
# Data saved for CTLT
# Data saved for CAT
# Data saved for CBOE
# Data saved for CBRE
# Data saved for CDW
# Data saved for CE
# Data saved for COR
# Data saved for CNC
# Data saved for CNP
# Data saved for CF
# Data saved for CHRW
# Data saved for CRL
# Data saved for SCHW
# Data saved for CHTR
# Data saved for CVX
# Data saved for CMG
# Data saved for CB
# Data saved for CHD
# Data saved for CI
# Data saved for CINF
# Data saved for CTAS
# Data saved for CSCO
# Data saved for C
# Data saved for CFG
# Data saved for CLX
# Data saved for CME
# Data saved for CMS
# Data saved for KO
# Data saved for CTSH
# Data saved for CL
# Data saved for CMCSA
# Data saved for CAG
# Data saved for COP
# Data saved for ED
# Data saved for STZ
# Data saved for CEG
# Data saved for COO
# Data saved for CPRT
# Data saved for GLW
# Data saved for CPAY
# Data saved for CTVA
# Data saved for CSGP
# Data saved for COST
# Data saved for CTRA
# Data saved for CRWD
# Data saved for CCI
# Data saved for CSX
# Data saved for CMI
# Data saved for CVS
# Data saved for DHR
# Data saved for DRI
# Data saved for DVA
# Data saved for DAY
# Data saved for DECK
# Data saved for DE
# Data saved for DAL
# Data saved for DVN
# Data saved for DXCM
# Data saved for FANG
# Data saved for DLR
# Data saved for DFS
# Data saved for DG
# Data saved for DLTR
# Data saved for D
# Data saved for DPZ
# Data saved for DOV
# Data saved for DOW
# Data saved for DHI
# Data saved for DTE
# Data saved for DUK
# Data saved for DD
# Data saved for EMN
# Data saved for ETN
# Data saved for EBAY
# Data saved for ECL
# Data saved for EIX
# Data saved for EW
# Data saved for EA
# Data saved for ELV
# Data saved for EMR
# Data saved for ENPH
# Data saved for ETR
# Data saved for EOG
# Data saved for EPAM
# Data saved for EQT
# Data saved for EFX
# Data saved for EQIX
# Data saved for EQR
# Data saved for ESS
# Data saved for EL
# Data saved for ETSY
# Data saved for EG
# Data saved for EVRG
# Data saved for ES
# Data saved for EXC
# Data saved for EXPE
# Data saved for EXPD
# Data saved for EXR
# Data saved for XOM
# Data saved for FFIV
# Data saved for FDS
# Data saved for FICO
# Data saved for FAST
# Data saved for FRT
# Data saved for FDX
# Data saved for FIS
# Data saved for FITB
# Data saved for FSLR
# Data saved for FE
# Data saved for FI
# Data saved for FMC
# Data saved for F
# Data saved for FTNT
# Data saved for FTV
# Data saved for FOXA
# Data saved for FOX
# Data saved for BEN
# Data saved for FCX
# Data saved for GRMN
# Data saved for IT
# Data saved for GE
# Data saved for GEHC
# Data saved for GEV
# Data saved for GEN
# Data saved for GNRC
# Data saved for GD
# Data saved for GIS
# Data saved for GM
# Data saved for GPC
# Data saved for GILD
# Data saved for GPN
# Data saved for GL
# Data saved for GDDY
# Data saved for GS
# Data saved for HAL
# Data saved for HIG
# Data saved for HAS
# Data saved for HCA
# Data saved for DOC
# Data saved for HSIC
# Data saved for HSY
# Data saved for HES
# Data saved for HPE
# Data saved for HLT
# Data saved for HOLX
# Data saved for HD
# Data saved for HON
# Data saved for HRL
# Data saved for HST
# Data saved for HWM
# Data saved for HPQ
# Data saved for HUBB
# Data saved for HUM
# Data saved for HBAN
# Data saved for HII
# Data saved for IBM
# Data saved for IEX
# Data saved for IDXX
# Data saved for ITW
# Data saved for INCY
# Data saved for IR
# Data saved for PODD
# Data saved for INTC
# Data saved for ICE
# Data saved for IFF
# Data saved for IP
# Data saved for IPG
# Data saved for INTU
# Data saved for ISRG
# Data saved for IVZ
# Data saved for INVH
# Data saved for IQV
# Data saved for IRM
# Data saved for JBHT
# Data saved for JBL
# Data saved for JKHY
# Data saved for J
# Data saved for JNJ
# Data saved for JCI
# Data saved for JPM
# Data saved for JNPR
# Data saved for K
# Data saved for KVUE
# Data saved for KDP
# Data saved for KEY
# Data saved for KEYS
# Data saved for KMB
# Data saved for KIM
# Data saved for KMI
# Data saved for KKR
# Data saved for KLAC
# Data saved for KHC
# Data saved for KR
# Data saved for LHX
# Data saved for LH
# Data saved for LRCX
# Data saved for LW
# Data saved for LVS
# Data saved for LDOS
# Data saved for LEN
# Data saved for LLY
# Data saved for LIN
# Data saved for LYV
# Data saved for LKQ
# Data saved for LMT
# Data saved for L
# Data saved for LOW
# Data saved for LULU
# Data saved for LYB
# Data saved for MTB
# Data saved for MRO
# Data saved for MPC
# Data saved for MKTX
# Data saved for MAR
# Data saved for MMC
# Data saved for MLM
# Data saved for MAS
# Data saved for MA
# Data saved for MTCH
# Data saved for MKC
# Data saved for MCD
# Data saved for MCK
# Data saved for MDT
# Data saved for MRK
# Data saved for META
# Data saved for MET
# Data saved for MTD
# Data saved for MGM
# Data saved for MCHP
# Data saved for MU
# Data saved for MSFT
# Data saved for MAA
# Data saved for MRNA
# Data saved for MHK
# Data saved for MOH
# Data saved for TAP
# Data saved for MDLZ
# Data saved for MPWR
# Data saved for MNST
# Data saved for MCO
# Data saved for MS
# Data saved for MOS
# Data saved for MSI
# Data saved for MSCI
# Data saved for NDAQ
# Data saved for NTAP
# Data saved for NFLX
# Data saved for NEM
# Data saved for NWSA
# Data saved for NWS
# Data saved for NEE
# Data saved for NKE
# Data saved for NI
# Data saved for NDSN
# Data saved for NSC
# Data saved for NTRS
# Data saved for NOC
# Data saved for NCLH
# Data saved for NRG
# Data saved for NUE
# Data saved for NVDA
# Data saved for NVR
# Data saved for NXPI
# Data saved for ORLY
# Data saved for OXY
# Data saved for ODFL
# Data saved for OMC
# Data saved for ON
# Data saved for OKE
# Data saved for ORCL
# Data saved for OTIS
# Data saved for PCAR
# Data saved for PKG
# Data saved for PANW
# Data saved for PARA
# Data saved for PH
# Data saved for PAYX
# Data saved for PAYC
# Data saved for PYPL
# Data saved for PNR
# Data saved for PEP
# Data saved for PFE
# Data saved for PCG
# Data saved for PM
# Data saved for PSX
# Data saved for PNW
# Data saved for PNC
# Data saved for POOL
# Data saved for PPG
# Data saved for PPL
# Data saved for PFG
# Data saved for PG
# Data saved for PGR
# Data saved for PLD
# Data saved for PRU
# Data saved for PEG
# Data saved for PTC
# Data saved for PSA
# Data saved for PHM
# Data saved for QRVO
# Data saved for PWR
# Data saved for QCOM
# Data saved for DGX
# Data saved for RL
# Data saved for RJF
# Data saved for RTX
# Data saved for O
# Data saved for REG
# Data saved for REGN
# Data saved for RF
# Data saved for RSG
# Data saved for RMD
# Data saved for RVTY
# Data saved for ROK
# Data saved for ROL
# Data saved for ROP
# Data saved for ROST
# Data saved for RCL
# Data saved for SPGI
# Data saved for CRM
# Data saved for SBAC
# Data saved for SLB
# Data saved for STX
# Data saved for SRE
# Data saved for NOW
# Data saved for SHW
# Data saved for SPG
# Data saved for SWKS
# Data saved for SJM
# Data saved for SW
# Data saved for SNA
# Data saved for SOLV
# Data saved for SO
# Data saved for LUV
# Data saved for SWK
# Data saved for SBUX
# Data saved for STT
# Data saved for STLD
# Data saved for STE
# Data saved for SYK
# Data saved for SMCI
# Data saved for SYF
# Data saved for SNPS
# Data saved for SYY
# Data saved for TMUS
# Data saved for TROW
# Data saved for TTWO
# Data saved for TPR
# Data saved for TRGP
# Data saved for TGT
# Data saved for TEL
# Data saved for TDY
# Data saved for TFX
# Data saved for TER
# Data saved for TSLA
# Data saved for TXN
# Data saved for TXT
# Data saved for TMO
# Data saved for TJX
# Data saved for TSCO
# Data saved for TT
# Data saved for TDG
# Data saved for TRV
# Data saved for TRMB
# Data saved for TFC
# Data saved for TYL
# Data saved for TSN
# Data saved for USB
# Data saved for UBER
# Data saved for UDR
# Data saved for ULTA
# Data saved for UNP
# Data saved for UAL
# Data saved for UPS
# Data saved for URI
# Data saved for UNH
# Data saved for UHS
# Data saved for VLO
# Data saved for VTR
# Data saved for VLTO
# Data saved for VRSN
# Data saved for VRSK
# Data saved for VZ
# Data saved for VRTX
# Data saved for VTRS
# Data saved for VICI
# Data saved for V
# Data saved for VST
# Data saved for VMC
# Data saved for WRB
# Data saved for GWW
# Data saved for WAB
# Data saved for WBA
# Data saved for WMT
# Data saved for DIS
# Data saved for WBD
# Data saved for WM
# Data saved for WAT
# Data saved for WEC
# Data saved for WFC
# Data saved for WELL
# Data saved for WST
# Data saved for WDC
# Data saved for WY
# Data saved for WMB
# Data saved for WTW
# Data saved for WYNN
# Data saved for XEL
# Data saved for XYL
# Data saved for YUM
# Error downloading data for ZBRA: HTTPSConnectionPool(host='query2.finance.yahoo.com', port=443): Read timed out.
# Data saved for ZBH
# Data saved for ZTS

# %%
import pandas as pd
import yfinance as yf
from requests_cache import CachedSession

# Create a cached session
session = CachedSession('yfinance.cache')
session.headers['User-agent'] = 'my-program/1.0'

# Get the S&P 500 tickers
sp500_tickers = pd.read_html('https://en.wikipedia.org/wiki/List_of_S%26P_500_companies')[0]['Symbol'].values.tolist()

# Loop through each ticker and download the data
total_tickers = len(sp500_tickers)
for i, ticker in enumerate(sp500_tickers):
    try:
        ticker_obj = yf.Ticker(ticker, session=session)
        data = {
            'info': pd.DataFrame([ticker_obj.info]),
            'financials': ticker_obj.financials.reset_index(),
            'quarterly_financials': ticker_obj.quarterly_financials.reset_index(),
            'balance_sheet': ticker_obj.balance_sheet.reset_index(),
            'quarterly_balance_sheet': ticker_obj.quarterly_balance_sheet.reset_index(),
            'cashflow': ticker_obj.cashflow.reset_index(),
            'quarterly_cashflow': ticker_obj.quarterly_cashflow.reset_index(),
        }
        
        # Create a separate Excel file for each stock
        with pd.ExcelWriter(f'{ticker}.xlsx') as writer:
            for key, value in data.items():
                value.to_excel(writer, sheet_name=key, index=False)
        
        progress = (i + 1) / total_tickers * 100
        print(f"Data saved for {ticker} ({progress:.2f}% complete)")
    except Exception as e:
        print(f"Error downloading data for {ticker}: {e}")
# Out:
# Data saved for MMM (0.20% complete)
# Data saved for AOS (0.40% complete)
# Data saved for ABT (0.60% complete)
# Data saved for ABBV (0.80% complete)
# Data saved for ACN (0.99% complete)
# Data saved for ADBE (1.19% complete)
# Data saved for AMD (1.39% complete)
# Data saved for AES (1.59% complete)
# Data saved for AFL (1.79% complete)
# Data saved for A (1.99% complete)
# Data saved for APD (2.19% complete)
# Data saved for ABNB (2.39% complete)
# Data saved for AKAM (2.58% complete)
# Data saved for ALB (2.78% complete)
# Data saved for ARE (2.98% complete)
# Data saved for ALGN (3.18% complete)
# Data saved for ALLE (3.38% complete)
# Data saved for LNT (3.58% complete)
# Data saved for ALL (3.78% complete)
# Data saved for GOOGL (3.98% complete)
# Data saved for GOOG (4.17% complete)
# Data saved for MO (4.37% complete)
# Data saved for AMZN (4.57% complete)
# Data saved for AMCR (4.77% complete)
# Data saved for AEE (4.97% complete)
# Data saved for AAL (5.17% complete)
# Data saved for AEP (5.37% complete)
# Data saved for AXP (5.57% complete)
# Data saved for AIG (5.77% complete)
# Data saved for AMT (5.96% complete)
# Data saved for AWK (6.16% complete)
# Data saved for AMP (6.36% complete)
# Data saved for AME (6.56% complete)
# Data saved for AMGN (6.76% complete)
# Data saved for APH (6.96% complete)
# Data saved for ADI (7.16% complete)
# Data saved for ANSS (7.36% complete)
# Data saved for AON (7.55% complete)
# Data saved for APA (7.75% complete)
# Data saved for AAPL (7.95% complete)
# Data saved for AMAT (8.15% complete)
# Data saved for APTV (8.35% complete)
# Data saved for ACGL (8.55% complete)
# Data saved for ADM (8.75% complete)
# Data saved for ANET (8.95% complete)
# Data saved for AJG (9.15% complete)
# Data saved for AIZ (9.34% complete)
# Data saved for T (9.54% complete)
# Data saved for ATO (9.74% complete)
# Data saved for ADSK (9.94% complete)
# Data saved for ADP (10.14% complete)
# Data saved for AZO (10.34% complete)
# Data saved for AVB (10.54% complete)
# Data saved for AVY (10.74% complete)
# Data saved for AXON (10.93% complete)
# Data saved for BKR (11.13% complete)
# Data saved for BALL (11.33% complete)
# Data saved for BAC (11.53% complete)
# Data saved for BK (11.73% complete)
# Data saved for BBWI (11.93% complete)
# Data saved for BAX (12.13% complete)
# Data saved for BDX (12.33% complete)
# Data saved for BRK.B (12.52% complete)
# Data saved for BBY (12.72% complete)
# Data saved for BIO (12.92% complete)
# Data saved for TECH (13.12% complete)
# Data saved for BIIB (13.32% complete)
# Data saved for BLK (13.52% complete)
# Data saved for BX (13.72% complete)
# Data saved for BA (13.92% complete)
# Data saved for BKNG (14.12% complete)
# Data saved for BWA (14.31% complete)
# Data saved for BSX (14.51% complete)
# Data saved for BMY (14.71% complete)
# Data saved for AVGO (14.91% complete)
# Data saved for BR (15.11% complete)
# Data saved for BRO (15.31% complete)
# Data saved for BF.B (15.51% complete)
# Data saved for BLDR (15.71% complete)
# Data saved for BG (15.90% complete)
# Data saved for BXP (16.10% complete)
# Data saved for CDNS (16.30% complete)
# Data saved for CZR (16.50% complete)
# Data saved for CPT (16.70% complete)
# Data saved for CPB (16.90% complete)
# Data saved for COF (17.10% complete)
# Data saved for CAH (17.30% complete)
# Data saved for KMX (17.50% complete)
# Data saved for CCL (17.69% complete)
# Data saved for CARR (17.89% complete)
# Data saved for CTLT (18.09% complete)
# Data saved for CAT (18.29% complete)
# Data saved for CBOE (18.49% complete)
# Data saved for CBRE (18.69% complete)
# Data saved for CDW (18.89% complete)
# Data saved for CE (19.09% complete)
# Data saved for COR (19.28% complete)
# Data saved for CNC (19.48% complete)
# Data saved for CNP (19.68% complete)
# Data saved for CF (19.88% complete)
# Data saved for CHRW (20.08% complete)
# Data saved for CRL (20.28% complete)
# Data saved for SCHW (20.48% complete)
# Data saved for CHTR (20.68% complete)
# Data saved for CVX (20.87% complete)
# Data saved for CMG (21.07% complete)
# Data saved for CB (21.27% complete)
# Data saved for CHD (21.47% complete)
# Data saved for CI (21.67% complete)
# Data saved for CINF (21.87% complete)
# Data saved for CTAS (22.07% complete)
# Data saved for CSCO (22.27% complete)
# Data saved for C (22.47% complete)
# Data saved for CFG (22.66% complete)
# Data saved for CLX (22.86% complete)
# Data saved for CME (23.06% complete)
# Data saved for CMS (23.26% complete)
# Data saved for KO (23.46% complete)
# Data saved for CTSH (23.66% complete)
# Data saved for CL (23.86% complete)
# Data saved for CMCSA (24.06% complete)
# Data saved for CAG (24.25% complete)
# Data saved for COP (24.45% complete)
# Data saved for ED (24.65% complete)
# Data saved for STZ (24.85% complete)
# Data saved for CEG (25.05% complete)
# Data saved for COO (25.25% complete)
# Data saved for CPRT (25.45% complete)
# Data saved for GLW (25.65% complete)
# Data saved for CPAY (25.84% complete)
# Data saved for CTVA (26.04% complete)
# Data saved for CSGP (26.24% complete)
# Data saved for COST (26.44% complete)
# Data saved for CTRA (26.64% complete)
# Data saved for CRWD (26.84% complete)
# Data saved for CCI (27.04% complete)
# Data saved for CSX (27.24% complete)
# Data saved for CMI (27.44% complete)
# Data saved for CVS (27.63% complete)
# Data saved for DHR (27.83% complete)
# Data saved for DRI (28.03% complete)
# Data saved for DVA (28.23% complete)
# Data saved for DAY (28.43% complete)
# Data saved for DECK (28.63% complete)
# Data saved for DE (28.83% complete)
# Data saved for DAL (29.03% complete)
# Data saved for DVN (29.22% complete)
# Data saved for DXCM (29.42% complete)
# Data saved for FANG (29.62% complete)
# Data saved for DLR (29.82% complete)
# Data saved for DFS (30.02% complete)
# Data saved for DG (30.22% complete)
# Data saved for DLTR (30.42% complete)
# Data saved for D (30.62% complete)
# Data saved for DPZ (30.82% complete)
# Data saved for DOV (31.01% complete)
# Data saved for DOW (31.21% complete)
# Data saved for DHI (31.41% complete)
# Data saved for DTE (31.61% complete)
# Data saved for DUK (31.81% complete)
# Data saved for DD (32.01% complete)
# Data saved for EMN (32.21% complete)
# Data saved for ETN (32.41% complete)
# Data saved for EBAY (32.60% complete)
# Data saved for ECL (32.80% complete)
# Data saved for EIX (33.00% complete)
# Data saved for EW (33.20% complete)
# Data saved for EA (33.40% complete)
# Data saved for ELV (33.60% complete)
# Data saved for EMR (33.80% complete)
# Data saved for ENPH (34.00% complete)
# Data saved for ETR (34.19% complete)
# Data saved for EOG (34.39% complete)
# Data saved for EPAM (34.59% complete)
# Data saved for EQT (34.79% complete)
# Data saved for EFX (34.99% complete)
# Data saved for EQIX (35.19% complete)
# Data saved for EQR (35.39% complete)
# Data saved for ESS (35.59% complete)
# Data saved for EL (35.79% complete)
# Data saved for ETSY (35.98% complete)
# Data saved for EG (36.18% complete)
# Data saved for EVRG (36.38% complete)
# Data saved for ES (36.58% complete)
# Data saved for EXC (36.78% complete)
# Data saved for EXPE (36.98% complete)
# Data saved for EXPD (37.18% complete)
# Data saved for EXR (37.38% complete)
# Data saved for XOM (37.57% complete)
# Data saved for FFIV (37.77% complete)
# Data saved for FDS (37.97% complete)
# Data saved for FICO (38.17% complete)
# Data saved for FAST (38.37% complete)
# Data saved for FRT (38.57% complete)
# Data saved for FDX (38.77% complete)
# Data saved for FIS (38.97% complete)
# Data saved for FITB (39.17% complete)
# Data saved for FSLR (39.36% complete)
# Data saved for FE (39.56% complete)
# Data saved for FI (39.76% complete)
# Data saved for FMC (39.96% complete)
# Data saved for F (40.16% complete)
# Data saved for FTNT (40.36% complete)
# Data saved for FTV (40.56% complete)
# Data saved for FOXA (40.76% complete)
# Data saved for FOX (40.95% complete)
# Data saved for BEN (41.15% complete)
# Data saved for FCX (41.35% complete)
# Data saved for GRMN (41.55% complete)
# Data saved for IT (41.75% complete)
# Data saved for GE (41.95% complete)
# Data saved for GEHC (42.15% complete)
# Data saved for GEV (42.35% complete)
# Data saved for GEN (42.54% complete)
# Data saved for GNRC (42.74% complete)
# Data saved for GD (42.94% complete)
# Data saved for GIS (43.14% complete)
# Data saved for GM (43.34% complete)
# Data saved for GPC (43.54% complete)
# Data saved for GILD (43.74% complete)
# Data saved for GPN (43.94% complete)
# Data saved for GL (44.14% complete)
# Data saved for GDDY (44.33% complete)
# Data saved for GS (44.53% complete)
# Data saved for HAL (44.73% complete)
# Data saved for HIG (44.93% complete)
# Data saved for HAS (45.13% complete)
# Data saved for HCA (45.33% complete)
# Data saved for DOC (45.53% complete)
# Data saved for HSIC (45.73% complete)
# Data saved for HSY (45.92% complete)
# Data saved for HES (46.12% complete)
# Data saved for HPE (46.32% complete)
# Data saved for HLT (46.52% complete)
# Data saved for HOLX (46.72% complete)
# Data saved for HD (46.92% complete)
# Data saved for HON (47.12% complete)
# Data saved for HRL (47.32% complete)
# Data saved for HST (47.51% complete)
# Data saved for HWM (47.71% complete)
# Data saved for HPQ (47.91% complete)
# Data saved for HUBB (48.11% complete)
# Data saved for HUM (48.31% complete)
# Data saved for HBAN (48.51% complete)
# Data saved for HII (48.71% complete)
# Data saved for IBM (48.91% complete)
# Data saved for IEX (49.11% complete)
# Data saved for IDXX (49.30% complete)
# Data saved for ITW (49.50% complete)
# Data saved for INCY (49.70% complete)
# Data saved for IR (49.90% complete)
# Data saved for PODD (50.10% complete)
# Data saved for INTC (50.30% complete)
# Data saved for ICE (50.50% complete)
# Data saved for IFF (50.70% complete)
# Data saved for IP (50.89% complete)
# Data saved for IPG (51.09% complete)
# Data saved for INTU (51.29% complete)
# Data saved for ISRG (51.49% complete)
# Data saved for IVZ (51.69% complete)
# Data saved for INVH (51.89% complete)
# Data saved for IQV (52.09% complete)
# Data saved for IRM (52.29% complete)
# Data saved for JBHT (52.49% complete)
# Data saved for JBL (52.68% complete)
# Data saved for JKHY (52.88% complete)
# Data saved for J (53.08% complete)
# Data saved for JNJ (53.28% complete)
# Data saved for JCI (53.48% complete)
# Data saved for JPM (53.68% complete)
# Data saved for JNPR (53.88% complete)
# Data saved for K (54.08% complete)
# Data saved for KVUE (54.27% complete)
# Data saved for KDP (54.47% complete)
# Data saved for KEY (54.67% complete)
# Data saved for KEYS (54.87% complete)
# Data saved for KMB (55.07% complete)
# Data saved for KIM (55.27% complete)
# Data saved for KMI (55.47% complete)
# Data saved for KKR (55.67% complete)
# Data saved for KLAC (55.86% complete)
# Data saved for KHC (56.06% complete)
# Data saved for KR (56.26% complete)
# Data saved for LHX (56.46% complete)
# Data saved for LH (56.66% complete)
# Data saved for LRCX (56.86% complete)
# Data saved for LW (57.06% complete)
# Data saved for LVS (57.26% complete)
# Data saved for LDOS (57.46% complete)
# Data saved for LEN (57.65% complete)
# Data saved for LLY (57.85% complete)
# Data saved for LIN (58.05% complete)
# Data saved for LYV (58.25% complete)
# Data saved for LKQ (58.45% complete)
# Data saved for LMT (58.65% complete)
# Data saved for L (58.85% complete)
# Data saved for LOW (59.05% complete)
# Data saved for LULU (59.24% complete)
# Data saved for LYB (59.44% complete)
# Data saved for MTB (59.64% complete)
# Data saved for MRO (59.84% complete)
# Data saved for MPC (60.04% complete)
# Data saved for MKTX (60.24% complete)
# Data saved for MAR (60.44% complete)
# Data saved for MMC (60.64% complete)
# Data saved for MLM (60.83% complete)
# Data saved for MAS (61.03% complete)
# Data saved for MA (61.23% complete)
# Data saved for MTCH (61.43% complete)
# Data saved for MKC (61.63% complete)
# Data saved for MCD (61.83% complete)
# Data saved for MCK (62.03% complete)
# Data saved for MDT (62.23% complete)
# Data saved for MRK (62.43% complete)
# Data saved for META (62.62% complete)
# Data saved for MET (62.82% complete)
# Data saved for MTD (63.02% complete)
# Data saved for MGM (63.22% complete)
# Data saved for MCHP (63.42% complete)
# Data saved for MU (63.62% complete)
# Data saved for MSFT (63.82% complete)
# Data saved for MAA (64.02% complete)
# Data saved for MRNA (64.21% complete)
# Data saved for MHK (64.41% complete)
# Data saved for MOH (64.61% complete)
# Data saved for TAP (64.81% complete)
# Data saved for MDLZ (65.01% complete)
# Data saved for MPWR (65.21% complete)
# Data saved for MNST (65.41% complete)
# Data saved for MCO (65.61% complete)
# Data saved for MS (65.81% complete)
# Data saved for MOS (66.00% complete)
# Data saved for MSI (66.20% complete)
# Data saved for MSCI (66.40% complete)
# Data saved for NDAQ (66.60% complete)
# Data saved for NTAP (66.80% complete)
# Data saved for NFLX (67.00% complete)
# Data saved for NEM (67.20% complete)
# Data saved for NWSA (67.40% complete)
# Data saved for NWS (67.59% complete)
# Data saved for NEE (67.79% complete)
# Data saved for NKE (67.99% complete)
# Data saved for NI (68.19% complete)
# Data saved for NDSN (68.39% complete)
# Data saved for NSC (68.59% complete)
# Data saved for NTRS (68.79% complete)
# Data saved for NOC (68.99% complete)
# Data saved for NCLH (69.18% complete)
# Data saved for NRG (69.38% complete)
# Data saved for NUE (69.58% complete)
# Data saved for NVDA (69.78% complete)
# Data saved for NVR (69.98% complete)
# Data saved for NXPI (70.18% complete)
# Data saved for ORLY (70.38% complete)
# Data saved for OXY (70.58% complete)
# Data saved for ODFL (70.78% complete)
# Data saved for OMC (70.97% complete)
# Data saved for ON (71.17% complete)
# Data saved for OKE (71.37% complete)
# Data saved for ORCL (71.57% complete)
# Data saved for OTIS (71.77% complete)
# Data saved for PCAR (71.97% complete)
# Data saved for PKG (72.17% complete)
# Data saved for PANW (72.37% complete)
# Data saved for PARA (72.56% complete)
# Data saved for PH (72.76% complete)
# Data saved for PAYX (72.96% complete)
# Data saved for PAYC (73.16% complete)
# Data saved for PYPL (73.36% complete)
# Data saved for PNR (73.56% complete)
# Data saved for PEP (73.76% complete)
# Data saved for PFE (73.96% complete)
# Data saved for PCG (74.16% complete)
# Data saved for PM (74.35% complete)
# Data saved for PSX (74.55% complete)
# Data saved for PNW (74.75% complete)
# Data saved for PNC (74.95% complete)
# Data saved for POOL (75.15% complete)
# Data saved for PPG (75.35% complete)
# Data saved for PPL (75.55% complete)
# Data saved for PFG (75.75% complete)
# Data saved for PG (75.94% complete)
# Data saved for PGR (76.14% complete)
# Data saved for PLD (76.34% complete)
# Data saved for PRU (76.54% complete)
# Data saved for PEG (76.74% complete)
# Data saved for PTC (76.94% complete)
# Data saved for PSA (77.14% complete)
# Data saved for PHM (77.34% complete)
# Data saved for QRVO (77.53% complete)
# Data saved for PWR (77.73% complete)
# Data saved for QCOM (77.93% complete)
# Data saved for DGX (78.13% complete)
# Data saved for RL (78.33% complete)
# Data saved for RJF (78.53% complete)
# Data saved for RTX (78.73% complete)
# Data saved for O (78.93% complete)
# Data saved for REG (79.13% complete)
# Data saved for REGN (79.32% complete)
# Data saved for RF (79.52% complete)
# Data saved for RSG (79.72% complete)
# Data saved for RMD (79.92% complete)
# Data saved for RVTY (80.12% complete)
# Data saved for ROK (80.32% complete)
# Data saved for ROL (80.52% complete)
# Data saved for ROP (80.72% complete)
# Data saved for ROST (80.91% complete)
# Data saved for RCL (81.11% complete)
# Data saved for SPGI (81.31% complete)
# Data saved for CRM (81.51% complete)
# Data saved for SBAC (81.71% complete)
# Data saved for SLB (81.91% complete)
# Data saved for STX (82.11% complete)
# Data saved for SRE (82.31% complete)
# Data saved for NOW (82.50% complete)
# Data saved for SHW (82.70% complete)
# Data saved for SPG (82.90% complete)
# Data saved for SWKS (83.10% complete)
# Data saved for SJM (83.30% complete)
# Data saved for SW (83.50% complete)
# Data saved for SNA (83.70% complete)
# Data saved for SOLV (83.90% complete)
# Data saved for SO (84.10% complete)
# Data saved for LUV (84.29% complete)
# Data saved for SWK (84.49% complete)
# Data saved for SBUX (84.69% complete)
# Data saved for STT (84.89% complete)
# Data saved for STLD (85.09% complete)
# Data saved for STE (85.29% complete)
# Data saved for SYK (85.49% complete)
# Data saved for SMCI (85.69% complete)
# Data saved for SYF (85.88% complete)
# Data saved for SNPS (86.08% complete)
# Data saved for SYY (86.28% complete)
# Data saved for TMUS (86.48% complete)
# Data saved for TROW (86.68% complete)
# Data saved for TTWO (86.88% complete)
# Data saved for TPR (87.08% complete)
# Data saved for TRGP (87.28% complete)
# Data saved for TGT (87.48% complete)
# Data saved for TEL (87.67% complete)
# Data saved for TDY (87.87% complete)
# Data saved for TFX (88.07% complete)
# Data saved for TER (88.27% complete)
# Data saved for TSLA (88.47% complete)
# Data saved for TXN (88.67% complete)
# Data saved for TXT (88.87% complete)
# Data saved for TMO (89.07% complete)
# Data saved for TJX (89.26% complete)
# Data saved for TSCO (89.46% complete)
# Data saved for TT (89.66% complete)
# Data saved for TDG (89.86% complete)
# Data saved for TRV (90.06% complete)
# Data saved for TRMB (90.26% complete)
# Data saved for TFC (90.46% complete)
# Data saved for TYL (90.66% complete)
# Data saved for TSN (90.85% complete)
# Data saved for USB (91.05% complete)
# Data saved for UBER (91.25% complete)
# Data saved for UDR (91.45% complete)
# Data saved for ULTA (91.65% complete)
# Data saved for UNP (91.85% complete)
# Data saved for UAL (92.05% complete)
# Data saved for UPS (92.25% complete)
# Data saved for URI (92.45% complete)
# Data saved for UNH (92.64% complete)
# Data saved for UHS (92.84% complete)
# Data saved for VLO (93.04% complete)
# Data saved for VTR (93.24% complete)
# Data saved for VLTO (93.44% complete)
# Data saved for VRSN (93.64% complete)
# Data saved for VRSK (93.84% complete)
# Data saved for VZ (94.04% complete)
# Data saved for VRTX (94.23% complete)
# Data saved for VTRS (94.43% complete)
# Data saved for VICI (94.63% complete)
# Data saved for V (94.83% complete)
# Data saved for VST (95.03% complete)
# Data saved for VMC (95.23% complete)
# Data saved for WRB (95.43% complete)
# Data saved for GWW (95.63% complete)
# Data saved for WAB (95.83% complete)
# Data saved for WBA (96.02% complete)
# Data saved for WMT (96.22% complete)
# Data saved for DIS (96.42% complete)
# Data saved for WBD (96.62% complete)
# Data saved for WM (96.82% complete)
# Data saved for WAT (97.02% complete)
# Data saved for WEC (97.22% complete)
# Data saved for WFC (97.42% complete)
# Data saved for WELL (97.61% complete)
# Data saved for WST (97.81% complete)
# Data saved for WDC (98.01% complete)
# Data saved for WY (98.21% complete)
# Data saved for WMB (98.41% complete)
# Data saved for WTW (98.61% complete)
# Data saved for WYNN (98.81% complete)
# Data saved for XEL (99.01% complete)
# Data saved for XYL (99.20% complete)
# Data saved for YUM (99.40% complete)
# Data saved for ZBRA (99.60% complete)
# Data saved for ZBH (99.80% complete)
# Data saved for ZTS (100.00% complete)

# %%
for column in financials.columns:
    print(f"The '{column}' column exists in the financials dataframe.")
# Out:
# The '2023-09-30 00:00:00' column exists in the financials dataframe.
# The '2022-09-30 00:00:00' column exists in the financials dataframe.
# The '2021-09-30 00:00:00' column exists in the financials dataframe.
# The '2020-09-30 00:00:00' column exists in the financials dataframe.
